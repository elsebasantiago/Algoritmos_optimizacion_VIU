# %% [markdown]
# <a href="https://colab.research.google.com/github/elsebasantiago/Algoritmos_optimizacion_VIU/blob/main/Algoritmos_Sebastian_Santiago_AG2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Actividad Guiada 2
# # Sebastián Santiago
# Link repositorio github
# https://github.com/elsebasantiago/Algoritmos_optimizacion_VIU

# %%
# Actividad Guiada 2, en clase
import numpy as np
import math
import matplotlib.pyplot as plt
import random

def f(x,y):
  return x**2 + y**2

def df(x,y):
  return np.array([2*x, 2*y])


alpha = 0.1
rango = 2.5
resolucion = 100
X = np.linspace(-rango, rango, resolucion)
Y = np.linspace(-rango, rango, resolucion)
Z = np.zeros((resolucion,resolucion))

max_iter = 500
for ix, x in enumerate(X):
  for iy, y in enumerate(Y):
    Z[ix,iy] = f(x,y)

plt.contourf(X,Y,Z,resolucion)
plt.colorbar()

P = [random.uniform(-rango,rango), random.uniform(-rango,rango)]
plt.plot(P[0],P[1],"o", c="white")
print(P)

for _ in range(max_iter):
  grad = df(P[0], P[1])
  P[0], P[1] = P[0] - alpha * grad[0], P[1] - alpha * grad[1]
  plt.plot(P[0],P[1],"o", c="red")

print(f'x = {P[0]}')
print(f'y = {P[1]}')
print(f'grad = {grad} ')
print(f'f = {f(P[0],P[1])} \n')

# Muestra la figura
plt.show()
# Out:
# [2.0771761215790736, 0.895255470368781]
# x = 7.28562506082479e-49
# y = 3.140078312570265e-49
# grad = [1.82140627e-48 7.85019578e-49]
# f = 6.294042433599235e-97

# %%
# Actividad Guiada 2, en clase
import numpy as np
import math
import matplotlib.pyplot as plt

def f(x,y):
  return x**2 + y**2

def df(x,y):
  return np.array([2*x, 2*y])

alpha = 0.1
rango = 2.5
max_iter = 10
x = np.random.uniform(-rango, rango)
y = np.random.uniform(-rango, rango)


print(f'x = {x}')
print(f'y = {y}')
print(f'grad = {df(x,y)} ')
print(f'f = {f(x,y)} \n')

resolucion = 50
X = np.linspace(-rango, rango, resolucion)
Y = np.linspace(-rango, rango, resolucion)
Z = np.zeros((resolucion,resolucion))

for ix, xx in enumerate(X):
  for iy, yy in enumerate(Y):
    Z[ix,iy] = f(xx,yy)

plt.contourf(X,Y,Z,resolucion)
plt.colorbar()

plt.plot(x,y,"o", c="white")


for _ in range(max_iter):
  grad = df(x,y)
  x = x - alpha * grad[0]
  y = y - alpha * grad[1]
  plt.plot(x,y,"x", c = "red")

plt.show()

print(f'x = {x}')
print(f'y = {y}')
print(f'grad = {grad} ')
print(f'f = {f(x,y)} \n')
# Out:
# x = -0.16561184617390268
# y = -1.4026051685902523
# grad = [-0.33122369 -2.80521034]
# f = 1.9947285425492185
# x = -0.017782436578677365
# y = -0.1506035832073925
# grad = [-0.04445609 -0.37650896]
# f = 0.02299765432558068

# %% [markdown]
# # Actividad Extra:
# ### Minimizar la función por descenso del gradiente, por medio de la derivada

# %%
# Actividad Guiada 2, en clase
import numpy as np
import math
import matplotlib.pyplot as plt

def f(x,y):
  return math.sin((1/2) * x**2 - (1/4) *  y**2 + 3) * math.cos(2 * x + 1 - math.exp(y) )

def df(x,y):

  g_xy = math.sin((1/2) * x**2 - (1/4) *  y**2 + 3)
  dg_dx = x * math.cos(1/2 * x**2 - 1/4 * y**2 + 3)
  dg_dy = - 1/ 2 * y * math.cos(1/2 * x**2 - 1/4 * y**2 + 3)

  h_xy = math.cos(2 * x + 1 - math.exp(y) )
  dh_dx = -2 * math.sin(2*x + 1 - math.exp(y))
  dh_dy =  math.sin(2*x + 1 - math.exp(y)) * math.exp(y)

  return np.array([dg_dx * h_xy + g_xy * dh_dx , dg_dy * h_xy + g_xy * dh_dy])

alpha = 0.1
rango = 2
max_iter = 1000
x = np.random.uniform(-rango, rango)
y = np.random.uniform(-rango, rango)


print(f'x = {x}')
print(f'y = {y}')
print(f'grad = {df(x,y)} ')
print(f'f = {f(x,y)} \n')

resolucion = 50
X = np.linspace(-rango, rango, resolucion)
Y = np.linspace(-rango, rango, resolucion)
Z = np.zeros((resolucion,resolucion))

for ix, xx in enumerate(X):
  for iy, yy in enumerate(Y):
    Z[ix,iy] = f(xx,yy)

plt.contourf(X,Y,Z,resolucion)
plt.colorbar()

plt.plot( x, y ,"o", c ="white")


for _ in range(max_iter):
  grad = df(x,y)
  x = x - alpha * grad[0]
  y = y - alpha * grad[1]
  plt.plot(x,y,"x", c = "red")

plt.show()

print(f'x = {x}')
print(f'y = {y}')
print(f'grad = {grad} ')
print(f'f = {f(x,y)} \n')
# Out:
# x = 0.19345176778619688
# y = -0.5867863142031351
# grad = [-0.43398439 -0.1083385 ]
# f = 0.1398769986165793
# x = 1.0996536824455039
# y = -2.8522431760725317
# grad = [2.04186897e-17 1.52868676e-15]
# f = -1.0

# %% [markdown]
# # Actividad Extra:
# ### Minimizar la función por descenso del gradiente, por medio del límite

# %%
# Actividad Guiada 2, en clase
import numpy as np
import math
import matplotlib.pyplot as plt

def f(P):
  return math.sin((1/2) * P[0]**2 - (1/4) *  P[1]**2 + 3) * math.cos(2 * P[0] + 1 - math.exp(P[1]) )

def df(P):

  h = 0.01
  T = np.copy(P)
  grad = np.zeros(2)
  for it, th in enumerate(P):
    T[it] = T[it] + h
    grad [it] = (f(T) - f(P)) / h

  return grad

alpha = 0.1
rango = 2
max_iter = 1000
x = np.random.uniform(-rango, rango)
y = np.random.uniform(-rango, rango)

punto = np.array([x,y])
print(f'x = {x}')
print(f'y = {y}')
print(f'grad = {df(punto)} ')
print(f'f = {f(punto)} \n')

resolucion = 50
X = np.linspace(-rango, rango, resolucion)
Y = np.linspace(-rango, rango, resolucion)
Z = np.zeros((resolucion,resolucion))

for ix, xx in enumerate(X):
  for iy, yy in enumerate(Y):
    Z[ix,iy] = f(np.array([xx,yy]))

plt.contourf(X,Y,Z,resolucion)
plt.colorbar()

plt.plot( x, y ,"o", c ="white")


for _ in range(max_iter):
  grad = df(np.array([x,y]))
  x = x - alpha * grad[0]
  y = y - alpha * grad[1]
  plt.plot(x,y,"x", c = "red")

plt.show()

print(f'x = {x}')
print(f'y = {y}')
print(f'grad = {grad} ')
print(f'f = {f(np.array([x,y]))} \n')
# Out:
# x = 1.3393698592062662
# y = 1.5118960374761636
# grad = [-1.15835365 -0.00851096]
# f = -0.11978477506724379
# x = 0.35654416993644955
# y = 0.8456210270074087
# grad = [-2.77555756e-15 -8.32667268e-15]
# f = 0.2072533702084925
